# %%
import os.path
import shutil
date = '251018'


importDirectory = os.path.join('/Users/sean/mbp_storage',date)

# %%
def Check_Make(path):
    if not os.path.isdir(path):
        os.mkdir(path)

# %%
sourceDirectory = os.path.join('/Users/sean/mbp_storage',date)
destDirectory = os.path.join('/Users/sean/mbp_storage/dropbox',date)
folder_struct = ['/Users/sean/mbp_storage/dropbox',
 destDirectory,
 os.path.join(destDirectory,'data'),
 os.path.join(destDirectory,'mainsailHiRes'),
 os.path.join(destDirectory,'mainsailScan'),
 os.path.join(destDirectory,'jibHiRes'),
 os.path.join(destDirectory,'jibScan')]

source_folders = ['portMain', 'stbMain', 'portJib', 'stbJib']
sub_folders = ['jpg', 'autScan_output']

for dest_folder in folder_struct:
    Check_Make(dest_folder)

dest_path = folder_struct[2]

source_path = os.path.join(sourceDirectory,'log')
try:
    files = os.listdir(source_path)
    for file in files:
        shutil.copy(os.path.join(source_path,file),os.path.join(dest_path,file))
except:
    print(source_path)
source_path = os.path.join(sourceDirectory,'event')
try:
    files = os.listdir(source_path)
    for file in files:
        shutil.copy(os.path.join(source_path,file),os.path.join(dest_path,file))
except:
    print(source_path)

dest_path = folder_struct[3]
for i in [0,1]:
    source_path = os.path.join(sourceDirectory,source_folders[i],sub_folders[0])
    try:
        files = os.listdir(source_path)
        for file in files:
            shutil.copy(os.path.join(source_path,file),os.path.join(dest_path,file))
    except:
        print(source_path)

dest_path = folder_struct[4]
for i in [0,1]:
    source_path = os.path.join(sourceDirectory,source_folders[i],sub_folders[1],sub_folders[0])
    try:
        files = os.listdir(source_path)
        for file in files:
            shutil.copy(os.path.join(source_path,file),os.path.join(dest_path,file))
    except:
        print(source_path)

dest_path = folder_struct[5]
for i in [2,3]:
    source_path = os.path.join(sourceDirectory,source_folders[i],sub_folders[0])
    try:
        files = os.listdir(source_path)
        for file in files:
            shutil.copy(os.path.join(source_path,file),os.path.join(dest_path,file))
    except:
        print(source_path)

dest_path = folder_struct[6]
for i in [2,3]:
    source_path = os.path.join(sourceDirectory,source_folders[i],sub_folders[1],sub_folders[0])
    try:
        files = os.listdir(source_path)
        for file in files:
            shutil.copy(os.path.join(source_path,file),os.path.join(dest_path,file))
    except:
        print(source_path)
# Out:
# /Users/sean/mbp_storage/251018/stbJib/autScan_output/jpg
